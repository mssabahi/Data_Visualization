# %%
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline
import numpy as np
from operator import add
import datetime
import os
import sys
import matplotlib
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 1000)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import pylab

# %%
pwd
# Out:
# 'C:\\Users\\ssabahi\\Desktop\\Plot_Generator\\Feb_18_2020\\NexGen'

# %%
start_date = datetime.datetime(2011, 1, 1)
end_date= datetime.datetime(2020, 3, 20)
#timestep in the impact output files
time_step = 0.08333333

# %% [markdown]
# The Information Needed to Enter
# Specify which IMPACT_locations should be plotted for comparison
# Use EXACTLY the name that IMPACT uses!
# This code plots 3 IMPACT locations. For more locations we
# need to add more if statement in the plotting section and
# modift IMPACT_color_ls.

# %%
IMPACT_locations = ['Broach Lake', 'Patterson Lake North West', 'Clearwater River upstream Mirror River']

# %% [markdown]
# Color lists for plotting

# %%
IMPACT_color_ls = ['navy','coral','g']
geom_m_EMMA_ls = ['black']
local_inflow_mean_color_ls = ['steelblue']
QG_color_ls = ['deepskyblue']

# %%
IMPACT_folder = 'NextGen_MT.ps55_Outputs'

# %%
#IMPACT results should be rounded for better plotting.
IMPACT_decimal_place = 7
#a list of all impact outputs
impactfile_list= os.listdir(IMPACT_folder)
IMPACT_output_files =[]

# %%
# To select different colors go to the following website:
     # https://www.rapidtables.com/web/css/css-color.html
# The cols_ls_1 is used for lakes with one samplig station.
cols_ls_1 = ['blue','green','black','yellow','darkred','khaki','darkgreen', 'cyan', 'mediumslateblue', 'olive','saddlebrown',
          'violet','dimgray','blue','green','black','yellow','darkred','khaki','darkgreen', 'cyan', 'mediumslateblue', 'olive','saddlebrown',
          'violet','dimgray','blue','green','black','yellow','darkred','khaki','darkgreen', 'cyan', 'mediumslateblue', 'olive','saddlebrown',
          'violet','dimgray','blue','green','black','yellow','darkred','khaki','darkgreen', 'cyan', 'mediumslateblue', 'olive','saddlebrown',
          'violet','dimgray']

    # The cols_ls_2 is used for lakes with more than one samplig station.
cols_ls_2 = ['blue','green','black','darkred','khaki','yellow']

# %% [markdown]
# Specify which EMMA_locations should be plotted and which files contain the data

# %%
EMMA_locations = ['PL','BeetL','FL','NL','LLI','BL','CR']
EMMA_folder_file = './EMMA/FFW_LW.xlsx'

#Select one lake from the IMPACT excel file results for water COPCs - Used for ploting
loc_name_plot = 'Forrest Lake north basin for Whitefish Conc'
#In case EMMA locations and IMPACT locations are different - set aliases
EMMA_location_alias = ['PL','BeetL','FL','NL','LLI','BL','CR'
                      ] 
#set the markers for plotting
EMMA_marker_ls = ["o","v","^","<",">","s","D","d",
              "p","H","X","o","v","^","<",">",
              "s","D"]

#Rename the COPC names based on the lab data
COPCs_dic = {'As':'Arsenic','COND':'Conductivity (Field)',
                      'Ca+':'Calcium','Ca':'Calcium','Cd':'Cadmium',
                      'Cl-':'Chloride','Cl':'Chloride','Co':'Cobalt',
                       'V':'Vanadium','Cr':'Chromium', 'Cs':'Cesium',
                      'Cu':'Copper', 'Fe':'Iron','NO3':'Nitrate',
                      'Mg+':'Magnesium', 'Mg':'Magnesium','Mn':'Manganese',
                      'Mo':'Molybdenum',
                      'NH3':'Ammonia as N','Na':'Sodium',
                      'NO3-':'Nitrate', 'Na+':'Sodium',
                      'Ni':'Nickel', 'Pb':'Lead', 'Pb-210':'Lead-210',
                      'Po-210':'Polonium-210', 'Ra-226':'Radium-226',
                      'Rn-222':'Radon-222', 'SO4':'Sulphate', 
                      'Se':'Selenium', 'Th-230':'Thorium-230',
                      'U':'Uranium', 'U-234':'Uranium-234',
                      'U-238':'Uranium-238', 
                      'Zn':'Zinc'}
    
    
#         if ( file_name.endswith('Northern pike Conc.xls') or file_name.endswith('Whitefish Conc.xls') ) :
#             IMPACT_output_files.append(file_name)

for file_name in impactfile_list:
    if ( file_name.endswith('Northern pike Conc.xls') ) :
        IMPACT_output_files.append(file_name)

# %%
IMPACT_output_files
# Out:
# ['Beet Lake for Northern pike Conc.xls',
#  'Broach Lake for Northern pike Conc.xls',
#  'Clearwater River upstream Mirror River for Northern pike Conc.xls',
#  'Forrest Lake north basin for Northern pike Conc.xls',
#  'Lloyd Lake Inlet for Northern pike Conc.xls',
#  'Patterson Lake North West for Northern pike Conc.xls',
#  'Patterson Lake South for Northern pike Conc.xls']

# %%
EMMA_file_sheet_name = 'FigureTable'
EMMA_file_sheet_name_stat = 'Stats_a_Entire Query Time'

# %%
# this dataframe is used to plot geometric means of COPCs
local_inflow_folder_file = './Local_Inflow/Local_Inflow.xlsx'
local_inflow_file_sheet_name = 'WaterBalance_output'

# %% [markdown]
# specify guidelines file

# %%
mode='water'

# %%
QG_folder_file = './WQG/WaterQualityGuidelines.xlsx'
if mode=='water':
    QG_file_sheet_name = 'WQG'
elif mode=='sediment':
    QG_file_sheet_name = 'SQG'
else:
    print('Enter an analysis mode at the top!')

# %% [markdown]
# Output save location

# %%
IMPACT_plots_folder = './plots/Impact_Plots_'+str(mode)
IMPACT_EMMA_Fish_Plots_folder = './plots/IMAPCT_EMMA_Plots_'+str(mode)
os.makedirs(IMPACT_plots_folder,exist_ok=True)
os.makedirs(IMPACT_EMMA_Fish_Plots_folder,exist_ok=True)

# %% [markdown]
# Import the raw data
# Datafrmae 1- EMMA
# Used to plot the sampled data-Scatter plot
# Here we need to enter the directory where the EMMA file is located and
# then mention the name of the excel file and respective sheets

# %%
#TODO: the skipfooter business is super risky, cutting off elements potentially

EMMA_df = pd.read_excel(EMMA_folder_file, sheet_name=EMMA_file_sheet_name)
EMMA_Stat_df = pd.read_excel(EMMA_folder_file, sheet_name=EMMA_file_sheet_name_stat,skiprows=3, skipfooter = 4)
EMMA_Stat_df.drop(['Unnamed: 0'], axis=1, inplace=True)
EMMA_df_header1 = list(EMMA_df.iloc[2,:5])
EMMA_df_header2 = list( map(add, list(map(str,EMMA_df.iloc[0,:])),  list(map(str,EMMA_df.iloc[1,:])) ))
EMMA_df_header2 = EMMA_df_header2[5:]
EMMA_df_header = (EMMA_df_header1+EMMA_df_header2)

#remove redundant rows
EMMA_df.drop(EMMA_df.index[[0,1,2]], inplace=True)
EMMA_df.columns = EMMA_df_header
print('The EMMA dataset has '+str(len(EMMA_locations))+ ' locations for the '+str(mode)+' sampling data')


EMMA_Stat_col_ls = ['Minimum', 'Percentile_5th', 'Percentile_50th', 'Percentile_95th', 'Maximum', 'Arithmetic_Mean', 'Geometric_Mean']
copcs_EMMA = EMMA_df.Parameter_ID.unique()

EMMA_col_TF_ls = list( (EMMA_df.columns[EMMA_df.columns.str.endswith('True')]) | (EMMA_df.columns[EMMA_df.columns.str.endswith('False')]) )
# Out:
# The EMMA dataset has 7 locations for the water sampling data

# %%
if mode=='water':
    #unit_micro = list(EMMA_df[EMMA_df['Units']=='µg/L']['Parameter_ID'].unique())
    #Change the microgram/l to miligram/l to be consistent with other dataframe data
    EMMA_df.loc[EMMA_df['Units']=='µg/L', EMMA_col_TF_ls] = EMMA_df.loc[EMMA_df['Units']=='µg/L', EMMA_col_TF_ls] * 0.001
    EMMA_Stat_df.loc[EMMA_Stat_df['Units']=='µg/L', EMMA_Stat_col_ls] = EMMA_Stat_df.loc[EMMA_Stat_df['Units']=='µg/L', EMMA_Stat_col_ls] * 0.001
    #TODO: maybe also rename the units?
elif mode=='sediment':
    #in sediment data everything is given in microg/mg which is equivalent to the mg/kg of impact
    EMMA_df.loc[EMMA_df['Units']=='Bq/g', EMMA_col_TF_ls] = EMMA_df.loc[EMMA_df['Units']=='Bq/g', EMMA_col_TF_ls] * 1000
    EMMA_Stat_df.loc[EMMA_Stat_df['Units']=='Bq/g', EMMA_Stat_col_ls] = EMMA_Stat_df.loc[EMMA_Stat_df['Units']=='Bq/g', EMMA_Stat_col_ls] * 1000
    
else:
    print('Enter an analysis mode at the top!')

# %% [markdown]
# Dataframe 2-Local Inflow File
# Used to plot COPCs' Geometric mean followed by the sediment-water interaction

# %%
IMPACT_output_files
# Out:
# ['Beet Lake for Northern pike Conc.xls',
#  'Broach Lake for Northern pike Conc.xls',
#  'Clearwater River upstream Mirror River for Northern pike Conc.xls',
#  'Forrest Lake north basin for Northern pike Conc.xls',
#  'Lloyd Lake Inlet for Northern pike Conc.xls',
#  'Patterson Lake North West for Northern pike Conc.xls',
#  'Patterson Lake South for Northern pike Conc.xls']

# %%
IMPACT_locations
# Out:
# ['Broach Lake',
#  'Patterson Lake North West',
#  'Clearwater River upstream Mirror River']

# %%
for file in IMPACT_output_files:
    #print(file)
    loc_name = file.split('for')[0]
    loc_name = loc_name.strip()

# %%
local_inflow_df = pd.read_excel(local_inflow_folder_file, sheet_name=local_inflow_file_sheet_name, skiprows=[0])
local_inflow_df.set_index('Contaminants', inplace=True)

#Rename the contaminant names based on the EMMA fromat
local_inflow_df.rename(columns = COPCs_dic,inplace=True)

#Creating a dictionary of selected IMPACT_locations defined above with 
#respective concentrations and time and rename the contaminants based on the 
#EMMA format     

IMPACT_df = {}

for file in IMPACT_output_files:
    #print(file)
    loc_name = file.split('for')[0]
    loc_name = loc_name.strip() # To remove unncessary white space
    for l in IMPACT_locations:
        if l == loc_name:
            print('Location ' + str(loc_name) + ' was found.')
            IMPACT_df_temp = pd.read_csv(IMPACT_folder + '/' + file, sep='\t', skiprows=[7], header=6)
            IMPACT_df_temp = IMPACT_df_temp.drop(IMPACT_df_temp.columns[IMPACT_df_temp.columns.str.startswith('Un')],1)
            IMPACT_df_temp['Timedelta'] = pd.to_timedelta(IMPACT_df_temp['Time'], unit='Y')
            IMPACT_df_temp['Date_Time'] = start_date + IMPACT_df_temp['Timedelta']
                
            IMPACT_df_temp.drop(columns=['Timedelta'], inplace=True) # remove this to make the next steps easier
            
            IMPACT_df_temp = IMPACT_df_temp[IMPACT_df_temp['Date_Time']<end_date]##########
    
            IMPACT_df[l] = IMPACT_df_temp
                
            IMPACT_df[l].rename(columns = COPCs_dic,inplace=True)
# Out:
# Location Broach Lake was found.
# Location Clearwater River upstream Mirror River was found.
# Location Patterson Lake North West was found.

# %%
local_inflow_df
# Out:
#                   Arsenic  Conductivity (Field)      Calcium   Cadmium  Chloride    Cobalt  Chromium    Cesium    Copper          Iron   Magnesium    Manganese  Molybdenum  Nitrate (as N)  Ammonia (as N)  Ammonia as N   Nitrate      Sodium    Nickel      Lead    Lead-210  Polonium-210  Radium-226  Radon-222  Sulphate  Selenium  Thorium-230   Uranium  Uranium-234  Uranium-238  Vanadium       Zinc
# Contaminants
# Sediment_input  10.478686               0.00000    23.715779  0.257873  3.707376  1.311782  5.485779  0.932560  2.352616    334.798058    8.966513  1257.059971    0.580901        0.112094        0.121854      0.000207  0.310151   10.799581  2.832545  3.155555  194.479000    197.843436   64.703058          0  9.405923  0.308154    20.809830  0.516141     6.377439     6.377439  0.337880  12.958253
# Water_meas       0.000130              23.26662     2.717433  0.000010  0.424804  0.000100  0.000500  0.000100  0.000213      0.067573    1.027413     0.012184    0.000102        0.012844        0.013962      0.000024  0.035538    1.237452  0.000104  0.000102    0.020238      0.005153    0.005537          0  1.077762  0.000100     0.010000  0.000101     6.377439     6.377439  0.000113   0.000890
# Water_calc       0.000130               0.00000     2.717433  0.000018  0.424804  0.000526  0.059282  0.000100  0.000788      0.067573    1.027413     0.012184    0.000184        0.012844        0.013962      0.000024  0.035538    1.237452  0.000326  0.000033    0.002743      0.002790    0.005538          0  1.077762  0.000016     0.009067  0.000027     0.000332     0.000332  0.000113   0.000890
# Sediment_meas    3.195999               0.00000  1629.436000  0.257873  0.000000  1.311782  5.485779  0.176139  2.352616  16040.400000  536.727200   402.602800    0.580901        0.000000        0.000000      0.000000  0.000000  104.945000  2.832545  3.155555  194.479000    157.045100   27.608530          0  0.000000  0.308154    20.809830  0.516141          NaN          NaN  8.091691  13.990960

# %% [markdown]
# Read the file that will contain the units and format it to drop all the
# unnecessary stuff:
# Remove the first 2 unnecessary columns from the first elements and one element
# from the lastvand add an another element called time to the end of the list
# Becareful: To plot sediment outpots unit_ls = unit_ls[1:-1] because in
# sediment we dont have outflow (second elements)

# %%
if mode=='water':
    startcolumn=2
elif mode=='sediment':
    startcolumn=1
else:
    print('Enter an analysis mode at the top!')

# %%
unit_ls_path = './'+ IMPACT_folder +'/'+ loc_name_plot+ '.xls'
unit_ls = list(pd.read_csv(unit_ls_path, sep='\t',skiprows=6).iloc[0,:])
unit_ls = unit_ls[startcolumn:-1]

unit_ls.append('Year')

# %% [markdown]
# To check that we have the same COPCs for all dataframes.
# The dataframe COPCs will be compared with COPCs in local inflow
# If they are not of equal length some COPCs will have to be added.

# %%
copcs_EMMA
# Out:
# array(['% Moisture', 'Aluminum', 'Antimony', 'Arsenic', 'Barium',
#        'Beryllium', 'Boron', 'Cadmium', 'Chromium', 'Cobalt', 'Copper',
#        'Iron', 'Lead', 'Lead-210', 'Manganese', 'Mercury', 'Molybdenum',
#        'Nickel', 'Polonium-210', 'Radium-226', 'Selenium', 'Silver',
#        'Strontium', 'Thallium', 'Thorium-230', 'Tin', 'Titanium',
#        'Uranium', 'Vanadium', 'Zinc'], dtype=object)

# %%
copcs_local_inflow = local_inflow_df.columns

if len(copcs_local_inflow)==len(copcs_EMMA):
    print(f'The size of copcs_EMMA is: {len(copcs_EMMA)}, equal to the size of copcs_local_inflow: {len(copcs_local_inflow)}' )
else:
    print('The copc arrays are not of equal length, we need to add the missing ones.')

copcs_missing =  list(set(copcs_local_inflow)-set(copcs_EMMA))
print('The missing copcs are '+ str(copcs_missing))

for m in copcs_missing:
    #TODO:correct units maybe?
    if mode=='water':
        toAdd= ['surface water_' + str(m).lower() + '_mg/l', str(m), 'mg/L', start_date, end_date]
    elif mode=='sediment':
        toAdd= ['sediment_' + str(m).lower() + '_mg/kg', str(m), 'mg/kg', start_date,end_date]
    else:
        print('Enter an analysis mode at the top!')
    
    EMMA_df = pd.concat([EMMA_df, pd.DataFrame([toAdd + ([np.nan] * (EMMA_df.shape[1]-len(toAdd)))], columns=EMMA_df.columns)], ignore_index=True)
    EMMA_Stat_df = pd.concat([EMMA_Stat_df, pd.DataFrame([toAdd + ([np.nan] * (EMMA_Stat_df.shape[1]-len(toAdd)))], columns=EMMA_Stat_df.columns)], ignore_index=True)
# Out:
# The copc arrays are not of equal length, we need to add the missing ones.
# The missing copcs are ['Nitrate (as N)', 'Sulphate', 'Chloride', 'Cesium', 'Uranium-238', 'Magnesium', 'Radon-222', 'Conductivity (Field)', 'Uranium-234', 'Sodium', 'Ammonia as N', 'Calcium', 'Ammonia (as N)', 'Nitrate']

# %% [markdown]
# Plotting the impact Dataframe

# %%
IMPACT_df.keys()
# Out:
# dict_keys(['Broach Lake', 'Clearwater River upstream Mirror River', 'Patterson Lake North West'])

# %%
#format input dates
#TODO: this needs to change to the dates that we enter at the top
dates_IMPACT = matplotlib.dates.date2num(IMPACT_df['Broach Lake']['Date_Time'])
#round IMPACT data:
for i in (IMPACT_df.keys()):
    IMPACT_df[i] = IMPACT_df[i].round(IMPACT_decimal_place)

# %%
#here is where the plotting happens:
fig, axes = plt.subplots(nrows=8, ncols=4, dpi = 200)

fig.set_figwidth(10)
fig.set_figheight(20)

axes = axes.ravel()
for m,i in enumerate(IMPACT_locations):

    for j,k in enumerate(IMPACT_df[i].columns[startcolumn:-1]):
        
        if m==0:
            axes[j].plot_date(dates_IMPACT, IMPACT_df[i][k], ls='--',marker= '',c=IMPACT_color_ls[m], label=i)
            axes[j].set_ylabel(k+ ' ' + '(' + unit_ls[j] + ')', fontsize=5)
            
            axes[j].xaxis.set_major_locator(mdates.YearLocator(1)) # 10 years of interval
            axes[j].xaxis.set_major_formatter(DateFormatter("%Y"))
            
            axes[j].tick_params(labelsize = 5)
           
        if m==1:
            axes[j].plot_date(dates_IMPACT, IMPACT_df[i][k], ls='-.',marker='',c=IMPACT_color_ls[m], label=i)
            
        if m==2:
            axes[j].plot_date(dates_IMPACT, IMPACT_df[i][k], ls=':',marker='',c=IMPACT_color_ls[m], label=i)
            
        fig.tight_layout()
   
        bbox = axes[j].get_tightbbox(fig.canvas.get_renderer())
        fig.savefig(str(IMPACT_plots_folder)+'/'+"{}.png".format(k),
              bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))    

        handles, labels = axes[j].get_legend_handles_labels()

fig.savefig(str(IMPACT_plots_folder)+'/IMPACT.png')
print('IMPACT figures are plotted and saved in '+str(IMPACT_plots_folder))
plt.close('all')
#print the labels
leg_fig = pylab.figure(figsize=(5,3), dpi=200)
leg_ax = fig.add_subplot(111)
leg_fig.legend(handles, labels, 'center', ncol=1)
leg_fig.savefig(str(IMPACT_plots_folder)+'/IMPACT_legend.png',bbox_inches='tight')
# Out:
# IMPACT figures are plotted and saved in ./plots/Impact_Plots_water

# %% [markdown]
# Adding EMMA data
# Creating a dictionary of EMMA dataframes for the selected EMMA_locations
#
# EMMA_df_s == Selected EMMA_dfCreating a dictionary of EMMA dataframes for the selected EMMA_locations
# EMMA_df_s == Selected EMMA_df
#
# Then:
# Creating two sets of dataframes for the measurements above and below detection limit
# T=Below DL
# F=Above DL

# %% [markdown]
# To apply the end_date to EMMA
# EMMA_df = EMMA_df[EMMA_df['Sample_DateTime']<end_date]
# This length of this list is used for marker shapes
# len(EMMA_location_alias)

# %%
EMMA_df = EMMA_df[EMMA_df['Sample_DateTime']<end_date]

# %%
EMMA_df_s = {} # Selected dataframe

for l in EMMA_location_alias:
    EMMA_df_temp = EMMA_df.filter(regex=(l))#filters all column entrys based on the name l
    EMMA_df_s[l] = EMMA_df_temp

print('The selected EMMA sampling locations for plotting are: '+str(EMMA_df_s.keys()))
# Out:
# The selected EMMA sampling locations for plotting are: dict_keys(['PL', 'BeetL', 'FL', 'NL', 'LLI', 'BL', 'CR'])

# %%
EMMA_df
# Out:
#                 Parameter_UID  Parameter_ID Units                             Sample_ID      Sample_DateTime BeetLFalse   BeetLTrue    BLFalse      BLTrue    FLFalse      FLTrue    LLIFalse     LLITrue    NLFalse      NLTrue    PLFalse      PLTrue
# 0         ffw_lw_% moisture_%    % Moisture     %       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00    18.5484         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 1         ffw_lw_% moisture_%    % Moisture     %       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00    18.0568         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 2         ffw_lw_% moisture_%    % Moisture     %       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00     20.429         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 3         ffw_lw_% moisture_%    % Moisture     %       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00    20.3041         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 4         ffw_lw_% moisture_%    % Moisture     %       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00    18.0251         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 5         ffw_lw_% moisture_%    % Moisture     %     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN    16.6537         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 6         ffw_lw_% moisture_%    % Moisture     %     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN    18.0515         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 7         ffw_lw_% moisture_%    % Moisture     %     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN    17.2382         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 8         ffw_lw_% moisture_%    % Moisture     %     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN    13.5147         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 9         ffw_lw_% moisture_%    % Moisture     %     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN    17.5526         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 10        ffw_lw_% moisture_%    % Moisture     %    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN    18.1146         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 11        ffw_lw_% moisture_%    % Moisture     %    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN    19.1533         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 12        ffw_lw_% moisture_%    % Moisture     %    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN    18.8645         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 13        ffw_lw_% moisture_%    % Moisture     %    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN    16.8376         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 14        ffw_lw_% moisture_%    % Moisture     %    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN    16.1672         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 15        ffw_lw_% moisture_%    % Moisture     %       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     19.3118         NaN        NaN         NaN        NaN         NaN
# 16        ffw_lw_% moisture_%    % Moisture     %       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     18.4054         NaN        NaN         NaN        NaN         NaN
# 17        ffw_lw_% moisture_%    % Moisture     %       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     19.0902         NaN        NaN         NaN        NaN         NaN
# 18        ffw_lw_% moisture_%    % Moisture     %       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     17.1488         NaN        NaN         NaN        NaN         NaN
# 19        ffw_lw_% moisture_%    % Moisture     %       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     19.4587         NaN        NaN         NaN        NaN         NaN
# 20        ffw_lw_% moisture_%    % Moisture     %      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN    18.8942         NaN        NaN         NaN
# 21        ffw_lw_% moisture_%    % Moisture     %      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN    17.8069         NaN        NaN         NaN
# 22        ffw_lw_% moisture_%    % Moisture     %      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN     19.933         NaN        NaN         NaN
# 23        ffw_lw_% moisture_%    % Moisture     %      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN    17.6884         NaN        NaN         NaN
# 24        ffw_lw_% moisture_%    % Moisture     %      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN    17.5143         NaN        NaN         NaN
# 25        ffw_lw_% moisture_%    % Moisture     %  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    16.9514         NaN
# 26        ffw_lw_% moisture_%    % Moisture     %  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    18.1618         NaN
# 27        ffw_lw_% moisture_%    % Moisture     %  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    17.3492         NaN
# 28        ffw_lw_% moisture_%    % Moisture     %  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    16.5958         NaN
# 29        ffw_lw_% moisture_%    % Moisture     %  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    19.1291         NaN
# 30       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00        NaN       0.492        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 31       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00        NaN       0.473        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 32       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00        NaN      0.5724        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 33       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN      0.5666        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 34       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00        NaN      0.4718        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 35       ffw_lw_aluminum_µg/g      Aluminum  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN        NaN      0.4222        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 36       ffw_lw_aluminum_µg/g      Aluminum  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN        NaN      0.4728        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 37       ffw_lw_aluminum_µg/g      Aluminum  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN      0.4428        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 38       ffw_lw_aluminum_µg/g      Aluminum  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN        NaN      0.3222        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 39       ffw_lw_aluminum_µg/g      Aluminum  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN        NaN      0.4542        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 40       ffw_lw_aluminum_µg/g      Aluminum  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.4752         NaN         NaN        NaN         NaN        NaN         NaN
# 41       ffw_lw_aluminum_µg/g      Aluminum  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.5164         NaN         NaN        NaN         NaN        NaN         NaN
# 42       ffw_lw_aluminum_µg/g      Aluminum  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.5046         NaN         NaN        NaN         NaN        NaN         NaN
# 43       ffw_lw_aluminum_µg/g      Aluminum  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.4286         NaN         NaN        NaN         NaN        NaN         NaN
# 44       ffw_lw_aluminum_µg/g      Aluminum  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.4056         NaN         NaN        NaN         NaN        NaN         NaN
# 45       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN       0.523        NaN         NaN        NaN         NaN
# 46       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN      0.4864        NaN         NaN        NaN         NaN
# 47       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN      0.5138        NaN         NaN        NaN         NaN
# 48       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN      0.4396        NaN         NaN        NaN         NaN
# 49       ffw_lw_aluminum_µg/g      Aluminum  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN      0.5292        NaN         NaN        NaN         NaN
# 50       ffw_lw_aluminum_µg/g      Aluminum  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN      0.5058        NaN         NaN
# 51       ffw_lw_aluminum_µg/g      Aluminum  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN      0.4636        NaN         NaN
# 52       ffw_lw_aluminum_µg/g      Aluminum  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN      0.5498        NaN         NaN
# 53       ffw_lw_aluminum_µg/g      Aluminum  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN      0.4592        NaN         NaN
# 54       ffw_lw_aluminum_µg/g      Aluminum  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN      0.4528        NaN         NaN
# 55       ffw_lw_aluminum_µg/g      Aluminum  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN      0.4326
# 56       ffw_lw_aluminum_µg/g      Aluminum  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN       0.477
# 57       ffw_lw_aluminum_µg/g      Aluminum  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN      0.4468
# 58       ffw_lw_aluminum_µg/g      Aluminum  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN      0.4202
# 59       ffw_lw_aluminum_µg/g      Aluminum  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN      0.5154
# 60       ffw_lw_antimony_µg/g      Antimony  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00        NaN      0.0246        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 61       ffw_lw_antimony_µg/g      Antimony  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00        NaN     0.02365        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 62       ffw_lw_antimony_µg/g      Antimony  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00        NaN     0.02862        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 63       ffw_lw_antimony_µg/g      Antimony  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN     0.02833        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 64       ffw_lw_antimony_µg/g      Antimony  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00        NaN     0.02359        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 65       ffw_lw_antimony_µg/g      Antimony  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN        NaN     0.02111        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 66       ffw_lw_antimony_µg/g      Antimony  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN        NaN     0.02364        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 67       ffw_lw_antimony_µg/g      Antimony  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN     0.02214        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 68       ffw_lw_antimony_µg/g      Antimony  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN        NaN     0.01611        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 69       ffw_lw_antimony_µg/g      Antimony  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN        NaN     0.02271        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 70       ffw_lw_antimony_µg/g      Antimony  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02376         NaN         NaN        NaN         NaN        NaN         NaN
# 71       ffw_lw_antimony_µg/g      Antimony  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02582         NaN         NaN        NaN         NaN        NaN         NaN
# 72       ffw_lw_antimony_µg/g      Antimony  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02523         NaN         NaN        NaN         NaN        NaN         NaN
# 73       ffw_lw_antimony_µg/g      Antimony  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02143         NaN         NaN        NaN         NaN        NaN         NaN
# 74       ffw_lw_antimony_µg/g      Antimony  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02028         NaN         NaN        NaN         NaN        NaN         NaN
# 75       ffw_lw_antimony_µg/g      Antimony  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02615        NaN         NaN        NaN         NaN
# 76       ffw_lw_antimony_µg/g      Antimony  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02432        NaN         NaN        NaN         NaN
# 77       ffw_lw_antimony_µg/g      Antimony  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02569        NaN         NaN        NaN         NaN
# 78       ffw_lw_antimony_µg/g      Antimony  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02198        NaN         NaN        NaN         NaN
# 79       ffw_lw_antimony_µg/g      Antimony  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02646        NaN         NaN        NaN         NaN
# 80       ffw_lw_antimony_µg/g      Antimony  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02529        NaN         NaN
# 81       ffw_lw_antimony_µg/g      Antimony  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02318        NaN         NaN
# 82       ffw_lw_antimony_µg/g      Antimony  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02749        NaN         NaN
# 83       ffw_lw_antimony_µg/g      Antimony  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02296        NaN         NaN
# 84       ffw_lw_antimony_µg/g      Antimony  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02264        NaN         NaN
# 85       ffw_lw_antimony_µg/g      Antimony  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02163
# 86       ffw_lw_antimony_µg/g      Antimony  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02385
# 87       ffw_lw_antimony_µg/g      Antimony  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02234
# 88       ffw_lw_antimony_µg/g      Antimony  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02101
# 89       ffw_lw_antimony_µg/g      Antimony  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02577
# 90        ffw_lw_arsenic_µg/g       Arsenic  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00    0.04428         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 91        ffw_lw_arsenic_µg/g       Arsenic  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00   0.021285         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 92        ffw_lw_arsenic_µg/g       Arsenic  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00   0.037206         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 93        ffw_lw_arsenic_µg/g       Arsenic  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN    0.014165        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 94        ffw_lw_arsenic_µg/g       Arsenic  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00   0.037744         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 95        ffw_lw_arsenic_µg/g       Arsenic  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN   0.012666         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 96        ffw_lw_arsenic_µg/g       Arsenic  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN   0.108744         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 97        ffw_lw_arsenic_µg/g       Arsenic  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN   0.104058         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 98        ffw_lw_arsenic_µg/g       Arsenic  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN   0.017721         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 99        ffw_lw_arsenic_µg/g       Arsenic  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN    0.04542         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 100       ffw_lw_arsenic_µg/g       Arsenic  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN   0.021384         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 101       ffw_lw_arsenic_µg/g       Arsenic  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN   0.061968         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 102       ffw_lw_arsenic_µg/g       Arsenic  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN   0.020184         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 103       ffw_lw_arsenic_µg/g       Arsenic  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.010715         NaN         NaN        NaN         NaN        NaN         NaN
# 104       ffw_lw_arsenic_µg/g       Arsenic  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN    0.02028         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 105       ffw_lw_arsenic_µg/g       Arsenic  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     0.01569         NaN        NaN         NaN        NaN         NaN
# 106       ffw_lw_arsenic_µg/g       Arsenic  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN     0.02432         NaN        NaN         NaN        NaN         NaN
# 107       ffw_lw_arsenic_µg/g       Arsenic  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN    0.015414         NaN        NaN         NaN        NaN         NaN
# 108       ffw_lw_arsenic_µg/g       Arsenic  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN    0.017584         NaN        NaN         NaN        NaN         NaN
# 109       ffw_lw_arsenic_µg/g       Arsenic  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN    0.050274         NaN        NaN         NaN        NaN         NaN
# 110       ffw_lw_arsenic_µg/g       Arsenic  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN   0.035406         NaN        NaN         NaN
# 111       ffw_lw_arsenic_µg/g       Arsenic  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN   0.039406         NaN        NaN         NaN
# 112       ffw_lw_arsenic_µg/g       Arsenic  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN    0.02749         NaN        NaN         NaN
# 113       ffw_lw_arsenic_µg/g       Arsenic  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN   0.032144         NaN        NaN         NaN
# 114       ffw_lw_arsenic_µg/g       Arsenic  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN   0.036224         NaN        NaN         NaN
# 115       ffw_lw_arsenic_µg/g       Arsenic  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN   0.028119         NaN
# 116       ffw_lw_arsenic_µg/g       Arsenic  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN   0.045315         NaN
# 117       ffw_lw_arsenic_µg/g       Arsenic  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN   0.109466         NaN
# 118       ffw_lw_arsenic_µg/g       Arsenic  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN   0.016808         NaN
# 119       ffw_lw_arsenic_µg/g       Arsenic  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN   0.043809         NaN
# 120        ffw_lw_barium_µg/g        Barium  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00    0.02952         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 121        ffw_lw_barium_µg/g        Barium  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00   0.021285         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 122        ffw_lw_barium_µg/g        Barium  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00   0.017172         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 123        ffw_lw_barium_µg/g        Barium  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN    0.014165        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 124        ffw_lw_barium_µg/g        Barium  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00        NaN    0.011795        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 125        ffw_lw_barium_µg/g        Barium  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN   0.040109         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 126        ffw_lw_barium_µg/g        Barium  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN   0.016548         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 127        ffw_lw_barium_µg/g        Barium  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN    0.01107         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 128        ffw_lw_barium_µg/g        Barium  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN   0.024165         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 129        ffw_lw_barium_µg/g        Barium  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN   0.034065         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 130        ffw_lw_barium_µg/g        Barium  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.01188         NaN         NaN        NaN         NaN        NaN         NaN
# 131        ffw_lw_barium_µg/g        Barium  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN   0.020656         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 132        ffw_lw_barium_µg/g        Barium  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.012615         NaN         NaN        NaN         NaN        NaN         NaN
# 133        ffw_lw_barium_µg/g        Barium  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN   0.008572         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 134        ffw_lw_barium_µg/g        Barium  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.01014         NaN         NaN        NaN         NaN        NaN         NaN
# 135        ffw_lw_barium_µg/g        Barium  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.013075        NaN         NaN        NaN         NaN
# 136        ffw_lw_barium_µg/g        Barium  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.01216        NaN         NaN        NaN         NaN
# 137        ffw_lw_barium_µg/g        Barium  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.012845        NaN         NaN        NaN         NaN
# 138        ffw_lw_barium_µg/g        Barium  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.01099        NaN         NaN        NaN         NaN
# 139        ffw_lw_barium_µg/g        Barium  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.01323        NaN         NaN        NaN         NaN
# 140        ffw_lw_barium_µg/g        Barium  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN    0.012645        NaN         NaN
# 141        ffw_lw_barium_µg/g        Barium  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.01159        NaN         NaN
# 142        ffw_lw_barium_µg/g        Barium  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN    0.02749         NaN        NaN         NaN
# 143        ffw_lw_barium_µg/g        Barium  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.01148        NaN         NaN
# 144        ffw_lw_barium_µg/g        Barium  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.01132        NaN         NaN
# 145        ffw_lw_barium_µg/g        Barium  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    0.04326         NaN
# 146        ffw_lw_barium_µg/g        Barium  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    0.01908         NaN
# 147        ffw_lw_barium_µg/g        Barium  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.01117
# 148        ffw_lw_barium_µg/g        Barium  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN    0.02101         NaN
# 149        ffw_lw_barium_µg/g        Barium  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN   0.018039         NaN
# 150     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00        NaN     0.00246        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 151     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00        NaN    0.002365        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 152     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00        NaN    0.002862        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 153     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN    0.002833        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 154     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00        NaN    0.002359        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 155     ffw_lw_beryllium_µg/g     Beryllium  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN        NaN    0.002111        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 156     ffw_lw_beryllium_µg/g     Beryllium  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN        NaN    0.002364        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 157     ffw_lw_beryllium_µg/g     Beryllium  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN    0.002214        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 158     ffw_lw_beryllium_µg/g     Beryllium  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN        NaN    0.001611        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 159     ffw_lw_beryllium_µg/g     Beryllium  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN        NaN    0.002271        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 160     ffw_lw_beryllium_µg/g     Beryllium  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.002376         NaN         NaN        NaN         NaN        NaN         NaN
# 161     ffw_lw_beryllium_µg/g     Beryllium  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.002582         NaN         NaN        NaN         NaN        NaN         NaN
# 162     ffw_lw_beryllium_µg/g     Beryllium  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.002523         NaN         NaN        NaN         NaN        NaN         NaN
# 163     ffw_lw_beryllium_µg/g     Beryllium  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.002143         NaN         NaN        NaN         NaN        NaN         NaN
# 164     ffw_lw_beryllium_µg/g     Beryllium  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN    0.002028         NaN         NaN        NaN         NaN        NaN         NaN
# 165     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.002615        NaN         NaN        NaN         NaN
# 166     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.002432        NaN         NaN        NaN         NaN
# 167     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.002569        NaN         NaN        NaN         NaN
# 168     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.002198        NaN         NaN        NaN         NaN
# 169     ffw_lw_beryllium_µg/g     Beryllium  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN    0.002646        NaN         NaN        NaN         NaN
# 170     ffw_lw_beryllium_µg/g     Beryllium  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN    0.002529        NaN         NaN
# 171     ffw_lw_beryllium_µg/g     Beryllium  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN    0.002318        NaN         NaN
# 172     ffw_lw_beryllium_µg/g     Beryllium  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN    0.002749        NaN         NaN
# 173     ffw_lw_beryllium_µg/g     Beryllium  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN    0.002296        NaN         NaN
# 174     ffw_lw_beryllium_µg/g     Beryllium  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN    0.002264        NaN         NaN
# 175     ffw_lw_beryllium_µg/g     Beryllium  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN    0.002163
# 176     ffw_lw_beryllium_µg/g     Beryllium  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN    0.002385
# 177     ffw_lw_beryllium_µg/g     Beryllium  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN    0.002234
# 178     ffw_lw_beryllium_µg/g     Beryllium  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN    0.002101
# 179     ffw_lw_beryllium_µg/g     Beryllium  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN    0.002577
# 180         ffw_lw_boron_µg/g         Boron  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00        NaN       0.246        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 181         ffw_lw_boron_µg/g         Boron  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00        NaN      0.2365        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 182         ffw_lw_boron_µg/g         Boron  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00        NaN      0.2862        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 183         ffw_lw_boron_µg/g         Boron  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN      0.2833        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 184         ffw_lw_boron_µg/g         Boron  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00        NaN      0.2359        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 185         ffw_lw_boron_µg/g         Boron  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN        NaN      0.2111        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 186         ffw_lw_boron_µg/g         Boron  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN        NaN      0.2364        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 187         ffw_lw_boron_µg/g         Boron  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN      0.2214        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 188         ffw_lw_boron_µg/g         Boron  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN        NaN      0.1611        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 189         ffw_lw_boron_µg/g         Boron  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN        NaN      0.2271        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 190         ffw_lw_boron_µg/g         Boron  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.2376         NaN         NaN        NaN         NaN        NaN         NaN
# 191         ffw_lw_boron_µg/g         Boron  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN      0.2582         NaN         NaN        NaN         NaN        NaN         NaN
# ...
# 836       ffw_lw_uranium_µg/g       Uranium  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN   0.0011925
# 837       ffw_lw_uranium_µg/g       Uranium  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN    0.001117
# 838       ffw_lw_uranium_µg/g       Uranium  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN   0.0010505
# 839       ffw_lw_uranium_µg/g       Uranium  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN   0.0012885
# 840      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00        NaN      0.0246        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 841      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00        NaN     0.02365        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 842      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00        NaN     0.02862        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 843      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00        NaN     0.02833        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 844      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00        NaN     0.02359        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 845      ffw_lw_vanadium_µg/g      Vanadium  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN        NaN     0.02111        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 846      ffw_lw_vanadium_µg/g      Vanadium  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN        NaN     0.02364        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 847      ffw_lw_vanadium_µg/g      Vanadium  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN     0.02214        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 848      ffw_lw_vanadium_µg/g      Vanadium  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN        NaN     0.01611        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 849      ffw_lw_vanadium_µg/g      Vanadium  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN        NaN     0.02271        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 850      ffw_lw_vanadium_µg/g      Vanadium  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02376         NaN         NaN        NaN         NaN        NaN         NaN
# 851      ffw_lw_vanadium_µg/g      Vanadium  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02582         NaN         NaN        NaN         NaN        NaN         NaN
# 852      ffw_lw_vanadium_µg/g      Vanadium  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02523         NaN         NaN        NaN         NaN        NaN         NaN
# 853      ffw_lw_vanadium_µg/g      Vanadium  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02143         NaN         NaN        NaN         NaN        NaN         NaN
# 854      ffw_lw_vanadium_µg/g      Vanadium  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN        NaN     0.02028         NaN         NaN        NaN         NaN        NaN         NaN
# 855      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02615        NaN         NaN        NaN         NaN
# 856      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02432        NaN         NaN        NaN         NaN
# 857      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02569        NaN         NaN        NaN         NaN
# 858      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02198        NaN         NaN        NaN         NaN
# 859      ffw_lw_vanadium_µg/g      Vanadium  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN     0.02646        NaN         NaN        NaN         NaN
# 860      ffw_lw_vanadium_µg/g      Vanadium  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02529        NaN         NaN
# 861      ffw_lw_vanadium_µg/g      Vanadium  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02318        NaN         NaN
# 862      ffw_lw_vanadium_µg/g      Vanadium  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02749        NaN         NaN
# 863      ffw_lw_vanadium_µg/g      Vanadium  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02296        NaN         NaN
# 864      ffw_lw_vanadium_µg/g      Vanadium  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN     0.02264        NaN         NaN
# 865      ffw_lw_vanadium_µg/g      Vanadium  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02163
# 866      ffw_lw_vanadium_µg/g      Vanadium  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02385
# 867      ffw_lw_vanadium_µg/g      Vanadium  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02234
# 868      ffw_lw_vanadium_µg/g      Vanadium  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02101
# 869      ffw_lw_vanadium_µg/g      Vanadium  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN     0.02577
# 870          ffw_lw_zinc_µg/g          Zinc  µg/g       Beet Lake FFL Lake Whitefish 01  2018-10-08 00:00:00      4.428         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 871          ffw_lw_zinc_µg/g          Zinc  µg/g       Beet Lake FFL Lake Whitefish 02  2018-10-08 00:00:00     4.0205         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 872          ffw_lw_zinc_µg/g          Zinc  µg/g       Beet Lake FFL Lake Whitefish 03  2018-10-08 00:00:00     4.0068         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 873          ffw_lw_zinc_µg/g          Zinc  µg/g       Beet Lake FFL Lake Whitefish 04  2018-10-08 00:00:00     3.9662         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 874          ffw_lw_zinc_µg/g          Zinc  µg/g       Beet Lake FFL Lake Whitefish 05  2018-10-08 00:00:00     3.7744         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 875          ffw_lw_zinc_µg/g          Zinc  µg/g     Broach Lake FFL Lake Whitefish 01  2018-10-11 00:00:00        NaN         NaN     4.8553         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 876          ffw_lw_zinc_µg/g          Zinc  µg/g     Broach Lake FFL Lake Whitefish 02  2018-10-11 00:00:00        NaN         NaN      4.728         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 877          ffw_lw_zinc_µg/g          Zinc  µg/g     Broach Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN     8.6346         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 878          ffw_lw_zinc_µg/g          Zinc  µg/g     Broach Lake FFL Lake Whitefish 04  2018-10-11 00:00:00        NaN         NaN     5.9607         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 879          ffw_lw_zinc_µg/g          Zinc  µg/g     Broach Lake FFL Lake Whitefish 05  2018-10-11 00:00:00        NaN         NaN     5.6775         NaN        NaN         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 880          ffw_lw_zinc_µg/g          Zinc  µg/g    Forrest Lake FFL Lake Whitefish 01  2018-10-10 00:00:00        NaN         NaN        NaN         NaN     4.9896         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 881          ffw_lw_zinc_µg/g          Zinc  µg/g    Forrest Lake FFL Lake Whitefish 02  2018-10-10 00:00:00        NaN         NaN        NaN         NaN     4.9058         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 882          ffw_lw_zinc_µg/g          Zinc  µg/g    Forrest Lake FFL Lake Whitefish 03  2018-10-10 00:00:00        NaN         NaN        NaN         NaN     4.5414         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 883          ffw_lw_zinc_µg/g          Zinc  µg/g    Forrest Lake FFL Lake Whitefish 04  2018-10-10 00:00:00        NaN         NaN        NaN         NaN     7.9291         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 884          ffw_lw_zinc_µg/g          Zinc  µg/g    Forrest Lake FFL Lake Whitefish 05  2018-10-10 00:00:00        NaN         NaN        NaN         NaN     4.2588         NaN         NaN         NaN        NaN         NaN        NaN         NaN
# 885          ffw_lw_zinc_µg/g          Zinc  µg/g       Lloyd Lake FFL Lake Whitefish 1  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN      4.4455         NaN        NaN         NaN        NaN         NaN
# 886          ffw_lw_zinc_µg/g          Zinc  µg/g       Lloyd Lake FFL Lake Whitefish 2  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN      4.1344         NaN        NaN         NaN        NaN         NaN
# 887          ffw_lw_zinc_µg/g          Zinc  µg/g       Lloyd Lake FFL Lake Whitefish 3  2018-08-10 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN      5.6518         NaN        NaN         NaN        NaN         NaN
# 888          ffw_lw_zinc_µg/g          Zinc  µg/g       Lloyd Lake FFL Lake Whitefish 4  2018-08-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN      5.2752         NaN        NaN         NaN        NaN         NaN
# 889          ffw_lw_zinc_µg/g          Zinc  µg/g       Lloyd Lake FFL Lake Whitefish 5  2018-09-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN       5.292         NaN        NaN         NaN        NaN         NaN
# 890          ffw_lw_zinc_µg/g          Zinc  µg/g      Naomi Lake FFL Lake Whitefish 01  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN     4.0464         NaN        NaN         NaN
# 891          ffw_lw_zinc_µg/g          Zinc  µg/g      Naomi Lake FFL Lake Whitefish 02  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN     4.1724         NaN        NaN         NaN
# 892          ffw_lw_zinc_µg/g          Zinc  µg/g      Naomi Lake FFL Lake Whitefish 03  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN     4.9482         NaN        NaN         NaN
# 893          ffw_lw_zinc_µg/g          Zinc  µg/g      Naomi Lake FFL Lake Whitefish 04  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN     5.2808         NaN        NaN         NaN
# 894          ffw_lw_zinc_µg/g          Zinc  µg/g      Naomi Lake FFL Lake Whitefish 05  2018-10-06 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN      4.528         NaN        NaN         NaN
# 895          ffw_lw_zinc_µg/g          Zinc  µg/g  Patterson Lake FFL Lake Whitefish 01  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN     5.1912         NaN
# 896          ffw_lw_zinc_µg/g          Zinc  µg/g  Patterson Lake FFL Lake Whitefish 02  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN      7.155         NaN
# 897          ffw_lw_zinc_µg/g          Zinc  µg/g  Patterson Lake FFL Lake Whitefish 03  2018-10-11 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN     20.106         NaN
# 898          ffw_lw_zinc_µg/g          Zinc  µg/g  Patterson Lake FFL Lake Whitefish 04  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN     4.6222         NaN
# 899          ffw_lw_zinc_µg/g          Zinc  µg/g  Patterson Lake FFL Lake Whitefish 05  2018-10-12 00:00:00        NaN         NaN        NaN         NaN        NaN         NaN         NaN         NaN        NaN         NaN     9.7926         NaN

# %% [markdown]
# seperate dfs for under and over DL

# %%
dates_EMMA = [pd.to_datetime(d) for d in EMMA_df['Sample_DateTime']]

dates_EMMA = matplotlib.dates.date2num(dates_EMMA)
EMMA_df_s_T = {}
EMMA_df_s_F = {}

for l in EMMA_location_alias:
    EMMA_df_temp_T = EMMA_df_s[l][EMMA_df_s[l].columns[EMMA_df_s[l].columns.str.endswith('True')]]
    EMMA_df_s_T[l] =  pd.concat([EMMA_df[['Parameter_ID','Units']],EMMA_df_temp_T, EMMA_df['Sample_DateTime'],
                                 pd.DataFrame(dates_EMMA,columns=['Time']) ],axis=1) 
           
    EMMA_df_temp_F = EMMA_df_s[l][EMMA_df_s[l].columns[EMMA_df_s[l].columns.str.endswith('False')]]
    EMMA_df_s_F[l] = pd.concat([EMMA_df[['Parameter_ID','Units']],EMMA_df_temp_F, EMMA_df['Sample_DateTime'],
                               pd.DataFrame(dates_EMMA,columns=['Time'])],axis=1)

# %%
EMMA_df_s_T['PL']
# Out:
#      Parameter_ID Units      PLTrue      Sample_DateTime      Time
# 0      % Moisture     %         NaN  2018-10-08 00:00:00  736975.0
# 1      % Moisture     %         NaN  2018-10-08 00:00:00  736975.0
# 2      % Moisture     %         NaN  2018-10-08 00:00:00  736975.0
# 3      % Moisture     %         NaN  2018-10-08 00:00:00  736975.0
# 4      % Moisture     %         NaN  2018-10-08 00:00:00  736975.0
# 5      % Moisture     %         NaN  2018-10-11 00:00:00  736978.0
# 6      % Moisture     %         NaN  2018-10-11 00:00:00  736978.0
# 7      % Moisture     %         NaN  2018-10-11 00:00:00  736978.0
# 8      % Moisture     %         NaN  2018-10-11 00:00:00  736978.0
# 9      % Moisture     %         NaN  2018-10-11 00:00:00  736978.0
# 10     % Moisture     %         NaN  2018-10-10 00:00:00  736977.0
# 11     % Moisture     %         NaN  2018-10-10 00:00:00  736977.0
# 12     % Moisture     %         NaN  2018-10-10 00:00:00  736977.0
# 13     % Moisture     %         NaN  2018-10-10 00:00:00  736977.0
# 14     % Moisture     %         NaN  2018-10-10 00:00:00  736977.0
# 15     % Moisture     %         NaN  2018-08-10 00:00:00  736916.0
# 16     % Moisture     %         NaN  2018-08-10 00:00:00  736916.0
# 17     % Moisture     %         NaN  2018-08-10 00:00:00  736916.0
# 18     % Moisture     %         NaN  2018-08-11 00:00:00  736917.0
# 19     % Moisture     %         NaN  2018-09-11 00:00:00  736948.0
# 20     % Moisture     %         NaN  2018-10-06 00:00:00  736973.0
# 21     % Moisture     %         NaN  2018-10-06 00:00:00  736973.0
# 22     % Moisture     %         NaN  2018-10-06 00:00:00  736973.0
# 23     % Moisture     %         NaN  2018-10-06 00:00:00  736973.0
# 24     % Moisture     %         NaN  2018-10-06 00:00:00  736973.0
# 25     % Moisture     %         NaN  2018-10-12 00:00:00  736979.0
# 26     % Moisture     %         NaN  2018-10-12 00:00:00  736979.0
# 27     % Moisture     %         NaN  2018-10-11 00:00:00  736978.0
# 28     % Moisture     %         NaN  2018-10-12 00:00:00  736979.0
# 29     % Moisture     %         NaN  2018-10-12 00:00:00  736979.0
# 30       Aluminum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 31       Aluminum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 32       Aluminum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 33       Aluminum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 34       Aluminum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 35       Aluminum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 36       Aluminum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 37       Aluminum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 38       Aluminum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 39       Aluminum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 40       Aluminum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 41       Aluminum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 42       Aluminum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 43       Aluminum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 44       Aluminum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 45       Aluminum  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 46       Aluminum  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 47       Aluminum  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 48       Aluminum  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 49       Aluminum  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 50       Aluminum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 51       Aluminum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 52       Aluminum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 53       Aluminum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 54       Aluminum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 55       Aluminum  µg/g      0.4326  2018-10-12 00:00:00  736979.0
# 56       Aluminum  µg/g       0.477  2018-10-12 00:00:00  736979.0
# 57       Aluminum  µg/g      0.4468  2018-10-11 00:00:00  736978.0
# 58       Aluminum  µg/g      0.4202  2018-10-12 00:00:00  736979.0
# 59       Aluminum  µg/g      0.5154  2018-10-12 00:00:00  736979.0
# 60       Antimony  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 61       Antimony  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 62       Antimony  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 63       Antimony  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 64       Antimony  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 65       Antimony  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 66       Antimony  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 67       Antimony  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 68       Antimony  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 69       Antimony  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 70       Antimony  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 71       Antimony  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 72       Antimony  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 73       Antimony  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 74       Antimony  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 75       Antimony  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 76       Antimony  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 77       Antimony  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 78       Antimony  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 79       Antimony  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 80       Antimony  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 81       Antimony  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 82       Antimony  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 83       Antimony  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 84       Antimony  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 85       Antimony  µg/g     0.02163  2018-10-12 00:00:00  736979.0
# 86       Antimony  µg/g     0.02385  2018-10-12 00:00:00  736979.0
# 87       Antimony  µg/g     0.02234  2018-10-11 00:00:00  736978.0
# 88       Antimony  µg/g     0.02101  2018-10-12 00:00:00  736979.0
# 89       Antimony  µg/g     0.02577  2018-10-12 00:00:00  736979.0
# 90        Arsenic  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 91        Arsenic  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 92        Arsenic  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 93        Arsenic  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 94        Arsenic  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 95        Arsenic  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 96        Arsenic  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 97        Arsenic  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 98        Arsenic  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 99        Arsenic  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 100       Arsenic  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 101       Arsenic  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 102       Arsenic  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 103       Arsenic  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 104       Arsenic  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 105       Arsenic  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 106       Arsenic  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 107       Arsenic  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 108       Arsenic  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 109       Arsenic  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 110       Arsenic  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 111       Arsenic  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 112       Arsenic  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 113       Arsenic  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 114       Arsenic  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 115       Arsenic  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 116       Arsenic  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 117       Arsenic  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 118       Arsenic  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 119       Arsenic  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 120        Barium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 121        Barium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 122        Barium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 123        Barium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 124        Barium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 125        Barium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 126        Barium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 127        Barium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 128        Barium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 129        Barium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 130        Barium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 131        Barium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 132        Barium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 133        Barium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 134        Barium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 135        Barium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 136        Barium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 137        Barium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 138        Barium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 139        Barium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 140        Barium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 141        Barium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 142        Barium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 143        Barium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 144        Barium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 145        Barium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 146        Barium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 147        Barium  µg/g     0.01117  2018-10-11 00:00:00  736978.0
# 148        Barium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 149        Barium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 150     Beryllium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 151     Beryllium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 152     Beryllium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 153     Beryllium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 154     Beryllium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 155     Beryllium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 156     Beryllium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 157     Beryllium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 158     Beryllium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 159     Beryllium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 160     Beryllium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 161     Beryllium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 162     Beryllium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 163     Beryllium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 164     Beryllium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 165     Beryllium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 166     Beryllium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 167     Beryllium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 168     Beryllium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 169     Beryllium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 170     Beryllium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 171     Beryllium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 172     Beryllium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 173     Beryllium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 174     Beryllium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 175     Beryllium  µg/g    0.002163  2018-10-12 00:00:00  736979.0
# 176     Beryllium  µg/g    0.002385  2018-10-12 00:00:00  736979.0
# 177     Beryllium  µg/g    0.002234  2018-10-11 00:00:00  736978.0
# 178     Beryllium  µg/g    0.002101  2018-10-12 00:00:00  736979.0
# 179     Beryllium  µg/g    0.002577  2018-10-12 00:00:00  736979.0
# 180         Boron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 181         Boron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 182         Boron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 183         Boron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 184         Boron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 185         Boron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 186         Boron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 187         Boron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 188         Boron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 189         Boron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 190         Boron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 191         Boron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 192         Boron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 193         Boron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 194         Boron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 195         Boron  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 196         Boron  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 197         Boron  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 198         Boron  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 199         Boron  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 200         Boron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 201         Boron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 202         Boron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 203         Boron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 204         Boron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 205         Boron  µg/g      0.2163  2018-10-12 00:00:00  736979.0
# 206         Boron  µg/g      0.2385  2018-10-12 00:00:00  736979.0
# 207         Boron  µg/g      0.2234  2018-10-11 00:00:00  736978.0
# 208         Boron  µg/g      0.2101  2018-10-12 00:00:00  736979.0
# 209         Boron  µg/g      0.2577  2018-10-12 00:00:00  736979.0
# 210       Cadmium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 211       Cadmium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 212       Cadmium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 213       Cadmium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 214       Cadmium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 215       Cadmium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 216       Cadmium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 217       Cadmium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 218       Cadmium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 219       Cadmium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 220       Cadmium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 221       Cadmium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 222       Cadmium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 223       Cadmium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 224       Cadmium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 225       Cadmium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 226       Cadmium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 227       Cadmium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 228       Cadmium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 229       Cadmium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 230       Cadmium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 231       Cadmium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 232       Cadmium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 233       Cadmium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 234       Cadmium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 235       Cadmium  µg/g    0.002163  2018-10-12 00:00:00  736979.0
# 236       Cadmium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 237       Cadmium  µg/g    0.002234  2018-10-11 00:00:00  736978.0
# 238       Cadmium  µg/g    0.002101  2018-10-12 00:00:00  736979.0
# 239       Cadmium  µg/g    0.002577  2018-10-12 00:00:00  736979.0
# 240      Chromium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 241      Chromium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 242      Chromium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 243      Chromium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 244      Chromium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 245      Chromium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 246      Chromium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 247      Chromium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 248      Chromium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 249      Chromium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 250      Chromium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 251      Chromium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 252      Chromium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 253      Chromium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 254      Chromium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 255      Chromium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 256      Chromium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 257      Chromium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 258      Chromium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 259      Chromium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 260      Chromium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 261      Chromium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 262      Chromium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 263      Chromium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 264      Chromium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 265      Chromium  µg/g     0.10815  2018-10-12 00:00:00  736979.0
# 266      Chromium  µg/g     0.11925  2018-10-12 00:00:00  736979.0
# 267      Chromium  µg/g      0.1117  2018-10-11 00:00:00  736978.0
# 268      Chromium  µg/g     0.10505  2018-10-12 00:00:00  736979.0
# 269      Chromium  µg/g     0.12885  2018-10-12 00:00:00  736979.0
# 270        Cobalt  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 271        Cobalt  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 272        Cobalt  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 273        Cobalt  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 274        Cobalt  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 275        Cobalt  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 276        Cobalt  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 277        Cobalt  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 278        Cobalt  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 279        Cobalt  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 280        Cobalt  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 281        Cobalt  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 282        Cobalt  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 283        Cobalt  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 284        Cobalt  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 285        Cobalt  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 286        Cobalt  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 287        Cobalt  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 288        Cobalt  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 289        Cobalt  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 290        Cobalt  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 291        Cobalt  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 292        Cobalt  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 293        Cobalt  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 294        Cobalt  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 295        Cobalt  µg/g    0.002163  2018-10-12 00:00:00  736979.0
# 296        Cobalt  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 297        Cobalt  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 298        Cobalt  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 299        Cobalt  µg/g    0.002577  2018-10-12 00:00:00  736979.0
# 300        Copper  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 301        Copper  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 302        Copper  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 303        Copper  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 304        Copper  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 305        Copper  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 306        Copper  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 307        Copper  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 308        Copper  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 309        Copper  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 310        Copper  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 311        Copper  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 312        Copper  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 313        Copper  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 314        Copper  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 315        Copper  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 316        Copper  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 317        Copper  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 318        Copper  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 319        Copper  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 320        Copper  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 321        Copper  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 322        Copper  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 323        Copper  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 324        Copper  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 325        Copper  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 326        Copper  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 327        Copper  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 328        Copper  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 329        Copper  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 330          Iron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 331          Iron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 332          Iron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 333          Iron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 334          Iron  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 335          Iron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 336          Iron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 337          Iron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 338          Iron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 339          Iron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 340          Iron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 341          Iron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 342          Iron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 343          Iron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 344          Iron  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 345          Iron  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 346          Iron  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 347          Iron  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 348          Iron  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 349          Iron  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 350          Iron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 351          Iron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 352          Iron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 353          Iron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 354          Iron  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 355          Iron  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 356          Iron  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 357          Iron  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 358          Iron  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 359          Iron  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 360          Lead  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 361          Lead  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 362          Lead  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 363          Lead  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 364          Lead  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 365          Lead  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 366          Lead  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 367          Lead  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 368          Lead  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 369          Lead  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 370          Lead  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 371          Lead  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 372          Lead  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 373          Lead  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 374          Lead  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 375          Lead  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 376          Lead  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 377          Lead  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 378          Lead  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 379          Lead  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 380          Lead  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 381          Lead  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 382          Lead  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 383          Lead  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 384          Lead  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 385          Lead  µg/g    0.002163  2018-10-12 00:00:00  736979.0
# 386          Lead  µg/g    0.002385  2018-10-12 00:00:00  736979.0
# 387          Lead  µg/g    0.002234  2018-10-11 00:00:00  736978.0
# 388          Lead  µg/g    0.002101  2018-10-12 00:00:00  736979.0
# 389          Lead  µg/g    0.002577  2018-10-12 00:00:00  736979.0
# 390      Lead-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 391      Lead-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 392      Lead-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 393      Lead-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 394      Lead-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 395      Lead-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 396      Lead-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 397      Lead-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 398      Lead-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 399      Lead-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 400      Lead-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 401      Lead-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 402      Lead-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 403      Lead-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 404      Lead-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 405      Lead-210  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 406      Lead-210  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 407      Lead-210  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 408      Lead-210  Bq/g         NaN  2018-08-11 00:00:00  736917.0
# 409      Lead-210  Bq/g         NaN  2018-09-11 00:00:00  736948.0
# 410      Lead-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 411      Lead-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 412      Lead-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 413      Lead-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 414      Lead-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 415      Lead-210  Bq/g   0.0010815  2018-10-12 00:00:00  736979.0
# 416      Lead-210  Bq/g    0.000954  2018-10-12 00:00:00  736979.0
# 417      Lead-210  Bq/g   0.0008936  2018-10-11 00:00:00  736978.0
# 418      Lead-210  Bq/g   0.0010505  2018-10-12 00:00:00  736979.0
# 419      Lead-210  Bq/g   0.0010308  2018-10-12 00:00:00  736979.0
# 420     Manganese  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 421     Manganese  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 422     Manganese  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 423     Manganese  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 424     Manganese  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 425     Manganese  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 426     Manganese  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 427     Manganese  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 428     Manganese  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 429     Manganese  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 430     Manganese  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 431     Manganese  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 432     Manganese  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 433     Manganese  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 434     Manganese  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 435     Manganese  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 436     Manganese  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 437     Manganese  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 438     Manganese  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 439     Manganese  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 440     Manganese  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 441     Manganese  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 442     Manganese  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 443     Manganese  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 444     Manganese  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 445     Manganese  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 446     Manganese  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 447     Manganese  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 448     Manganese  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 449     Manganese  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 450       Mercury  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 451       Mercury  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 452       Mercury  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 453       Mercury  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 454       Mercury  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 455       Mercury  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 456       Mercury  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 457       Mercury  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 458       Mercury  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 459       Mercury  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 460       Mercury  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 461       Mercury  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 462       Mercury  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 463       Mercury  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 464       Mercury  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 465       Mercury  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 466       Mercury  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 467       Mercury  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 468       Mercury  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 469       Mercury  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 470       Mercury  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 471       Mercury  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 472       Mercury  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 473       Mercury  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 474       Mercury  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 475       Mercury  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 476       Mercury  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 477       Mercury  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 478       Mercury  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 479       Mercury  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 480    Molybdenum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 481    Molybdenum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 482    Molybdenum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 483    Molybdenum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 484    Molybdenum  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 485    Molybdenum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 486    Molybdenum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 487    Molybdenum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 488    Molybdenum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 489    Molybdenum  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 490    Molybdenum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 491    Molybdenum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 492    Molybdenum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 493    Molybdenum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 494    Molybdenum  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 495    Molybdenum  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 496    Molybdenum  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 497    Molybdenum  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 498    Molybdenum  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 499    Molybdenum  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 500    Molybdenum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 501    Molybdenum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 502    Molybdenum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 503    Molybdenum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 504    Molybdenum  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 505    Molybdenum  µg/g     0.02163  2018-10-12 00:00:00  736979.0
# 506    Molybdenum  µg/g     0.02385  2018-10-12 00:00:00  736979.0
# 507    Molybdenum  µg/g     0.02234  2018-10-11 00:00:00  736978.0
# 508    Molybdenum  µg/g     0.02101  2018-10-12 00:00:00  736979.0
# 509    Molybdenum  µg/g     0.02577  2018-10-12 00:00:00  736979.0
# 510        Nickel  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 511        Nickel  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 512        Nickel  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 513        Nickel  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 514        Nickel  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 515        Nickel  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 516        Nickel  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 517        Nickel  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 518        Nickel  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 519        Nickel  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 520        Nickel  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 521        Nickel  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 522        Nickel  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 523        Nickel  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 524        Nickel  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 525        Nickel  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 526        Nickel  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 527        Nickel  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 528        Nickel  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 529        Nickel  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 530        Nickel  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 531        Nickel  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 532        Nickel  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 533        Nickel  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 534        Nickel  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 535        Nickel  µg/g    0.010815  2018-10-12 00:00:00  736979.0
# 536        Nickel  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 537        Nickel  µg/g     0.01117  2018-10-11 00:00:00  736978.0
# 538        Nickel  µg/g    0.010505  2018-10-12 00:00:00  736979.0
# 539        Nickel  µg/g    0.012885  2018-10-12 00:00:00  736979.0
# 540  Polonium-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 541  Polonium-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 542  Polonium-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 543  Polonium-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 544  Polonium-210  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 545  Polonium-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 546  Polonium-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 547  Polonium-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 548  Polonium-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 549  Polonium-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 550  Polonium-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 551  Polonium-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 552  Polonium-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 553  Polonium-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 554  Polonium-210  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 555  Polonium-210  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 556  Polonium-210  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 557  Polonium-210  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 558  Polonium-210  Bq/g         NaN  2018-08-11 00:00:00  736917.0
# 559  Polonium-210  Bq/g         NaN  2018-09-11 00:00:00  736948.0
# 560  Polonium-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 561  Polonium-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 562  Polonium-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 563  Polonium-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 564  Polonium-210  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 565  Polonium-210  Bq/g         NaN  2018-10-12 00:00:00  736979.0
# 566  Polonium-210  Bq/g         NaN  2018-10-12 00:00:00  736979.0
# 567  Polonium-210  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 568  Polonium-210  Bq/g         NaN  2018-10-12 00:00:00  736979.0
# 569  Polonium-210  Bq/g         NaN  2018-10-12 00:00:00  736979.0
# 570    Radium-226  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 571    Radium-226  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 572    Radium-226  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 573    Radium-226  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 574    Radium-226  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 575    Radium-226  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 576    Radium-226  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 577    Radium-226  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 578    Radium-226  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 579    Radium-226  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 580    Radium-226  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 581    Radium-226  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 582    Radium-226  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 583    Radium-226  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 584    Radium-226  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 585    Radium-226  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 586    Radium-226  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 587    Radium-226  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 588    Radium-226  Bq/g         NaN  2018-08-11 00:00:00  736917.0
# 589    Radium-226  Bq/g         NaN  2018-09-11 00:00:00  736948.0
# 590    Radium-226  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 591    Radium-226  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 592    Radium-226  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 593    Radium-226  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 594    Radium-226  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 595    Radium-226  Bq/g   6.489e-05  2018-10-12 00:00:00  736979.0
# 596    Radium-226  Bq/g   7.155e-05  2018-10-12 00:00:00  736979.0
# 597    Radium-226  Bq/g   6.702e-05  2018-10-11 00:00:00  736978.0
# 598    Radium-226  Bq/g   6.303e-05  2018-10-12 00:00:00  736979.0
# 599    Radium-226  Bq/g   5.154e-05  2018-10-12 00:00:00  736979.0
# 600      Selenium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 601      Selenium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 602      Selenium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 603      Selenium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 604      Selenium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 605      Selenium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 606      Selenium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 607      Selenium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 608      Selenium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 609      Selenium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 610      Selenium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 611      Selenium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 612      Selenium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 613      Selenium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 614      Selenium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 615      Selenium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 616      Selenium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 617      Selenium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 618      Selenium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 619      Selenium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 620      Selenium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 621      Selenium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 622      Selenium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 623      Selenium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 624      Selenium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 625      Selenium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 626      Selenium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 627      Selenium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 628      Selenium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 629      Selenium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 630        Silver  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 631        Silver  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 632        Silver  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 633        Silver  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 634        Silver  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 635        Silver  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 636        Silver  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 637        Silver  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 638        Silver  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 639        Silver  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 640        Silver  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 641        Silver  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 642        Silver  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 643        Silver  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 644        Silver  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 645        Silver  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 646        Silver  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 647        Silver  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 648        Silver  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 649        Silver  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 650        Silver  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 651        Silver  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 652        Silver  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 653        Silver  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 654        Silver  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 655        Silver  µg/g    0.002163  2018-10-12 00:00:00  736979.0
# 656        Silver  µg/g    0.002385  2018-10-12 00:00:00  736979.0
# 657        Silver  µg/g    0.002234  2018-10-11 00:00:00  736978.0
# 658        Silver  µg/g    0.002101  2018-10-12 00:00:00  736979.0
# 659        Silver  µg/g    0.002577  2018-10-12 00:00:00  736979.0
# 660     Strontium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 661     Strontium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 662     Strontium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 663     Strontium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 664     Strontium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 665     Strontium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 666     Strontium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 667     Strontium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 668     Strontium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 669     Strontium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 670     Strontium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 671     Strontium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 672     Strontium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 673     Strontium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 674     Strontium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 675     Strontium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 676     Strontium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 677     Strontium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 678     Strontium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 679     Strontium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 680     Strontium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 681     Strontium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 682     Strontium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 683     Strontium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 684     Strontium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 685     Strontium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 686     Strontium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 687     Strontium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 688     Strontium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 689     Strontium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 690      Thallium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 691      Thallium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 692      Thallium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 693      Thallium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 694      Thallium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 695      Thallium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 696      Thallium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 697      Thallium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 698      Thallium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 699      Thallium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 700      Thallium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 701      Thallium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 702      Thallium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 703      Thallium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 704      Thallium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 705      Thallium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 706      Thallium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 707      Thallium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 708      Thallium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 709      Thallium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 710      Thallium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 711      Thallium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 712      Thallium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 713      Thallium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 714      Thallium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 715      Thallium  µg/g    0.010815  2018-10-12 00:00:00  736979.0
# 716      Thallium  µg/g    0.011925  2018-10-12 00:00:00  736979.0
# 717      Thallium  µg/g     0.01117  2018-10-11 00:00:00  736978.0
# 718      Thallium  µg/g    0.010505  2018-10-12 00:00:00  736979.0
# 719      Thallium  µg/g    0.012885  2018-10-12 00:00:00  736979.0
# 720   Thorium-230  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 721   Thorium-230  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 722   Thorium-230  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 723   Thorium-230  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 724   Thorium-230  Bq/g         NaN  2018-10-08 00:00:00  736975.0
# 725   Thorium-230  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 726   Thorium-230  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 727   Thorium-230  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 728   Thorium-230  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 729   Thorium-230  Bq/g         NaN  2018-10-11 00:00:00  736978.0
# 730   Thorium-230  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 731   Thorium-230  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 732   Thorium-230  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 733   Thorium-230  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 734   Thorium-230  Bq/g         NaN  2018-10-10 00:00:00  736977.0
# 735   Thorium-230  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 736   Thorium-230  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 737   Thorium-230  Bq/g         NaN  2018-08-10 00:00:00  736916.0
# 738   Thorium-230  Bq/g         NaN  2018-08-11 00:00:00  736917.0
# 739   Thorium-230  Bq/g         NaN  2018-09-11 00:00:00  736948.0
# 740   Thorium-230  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 741   Thorium-230  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 742   Thorium-230  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 743   Thorium-230  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 744   Thorium-230  Bq/g         NaN  2018-10-06 00:00:00  736973.0
# 745   Thorium-230  Bq/g  0.00010815  2018-10-12 00:00:00  736979.0
# 746   Thorium-230  Bq/g   0.0001431  2018-10-12 00:00:00  736979.0
# 747   Thorium-230  Bq/g  0.00013404  2018-10-11 00:00:00  736978.0
# 748   Thorium-230  Bq/g  0.00014707  2018-10-12 00:00:00  736979.0
# 749   Thorium-230  Bq/g  0.00012885  2018-10-12 00:00:00  736979.0
# 750           Tin  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 751           Tin  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 752           Tin  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 753           Tin  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 754           Tin  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 755           Tin  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 756           Tin  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 757           Tin  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 758           Tin  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 759           Tin  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 760           Tin  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 761           Tin  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 762           Tin  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 763           Tin  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 764           Tin  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 765           Tin  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 766           Tin  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 767           Tin  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 768           Tin  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 769           Tin  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 770           Tin  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 771           Tin  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 772           Tin  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 773           Tin  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 774           Tin  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 775           Tin  µg/g    0.010815  2018-10-12 00:00:00  736979.0
# 776           Tin  µg/g    0.011925  2018-10-12 00:00:00  736979.0
# 777           Tin  µg/g     0.01117  2018-10-11 00:00:00  736978.0
# 778           Tin  µg/g    0.010505  2018-10-12 00:00:00  736979.0
# 779           Tin  µg/g    0.012885  2018-10-12 00:00:00  736979.0
# 780      Titanium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 781      Titanium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 782      Titanium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 783      Titanium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 784      Titanium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 785      Titanium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 786      Titanium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 787      Titanium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 788      Titanium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 789      Titanium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 790      Titanium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 791      Titanium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 792      Titanium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 793      Titanium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 794      Titanium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 795      Titanium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 796      Titanium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 797      Titanium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 798      Titanium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 799      Titanium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 800      Titanium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 801      Titanium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 802      Titanium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 803      Titanium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 804      Titanium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 805      Titanium  µg/g    0.010815  2018-10-12 00:00:00  736979.0
# 806      Titanium  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 807      Titanium  µg/g     0.01117  2018-10-11 00:00:00  736978.0
# 808      Titanium  µg/g    0.010505  2018-10-12 00:00:00  736979.0
# 809      Titanium  µg/g    0.012885  2018-10-12 00:00:00  736979.0
# 810       Uranium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 811       Uranium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 812       Uranium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 813       Uranium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 814       Uranium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 815       Uranium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 816       Uranium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 817       Uranium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 818       Uranium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 819       Uranium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 820       Uranium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 821       Uranium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 822       Uranium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 823       Uranium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 824       Uranium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 825       Uranium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 826       Uranium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 827       Uranium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 828       Uranium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 829       Uranium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 830       Uranium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 831       Uranium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 832       Uranium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 833       Uranium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 834       Uranium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 835       Uranium  µg/g   0.0010815  2018-10-12 00:00:00  736979.0
# 836       Uranium  µg/g   0.0011925  2018-10-12 00:00:00  736979.0
# 837       Uranium  µg/g    0.001117  2018-10-11 00:00:00  736978.0
# 838       Uranium  µg/g   0.0010505  2018-10-12 00:00:00  736979.0
# 839       Uranium  µg/g   0.0012885  2018-10-12 00:00:00  736979.0
# 840      Vanadium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 841      Vanadium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 842      Vanadium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 843      Vanadium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 844      Vanadium  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 845      Vanadium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 846      Vanadium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 847      Vanadium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 848      Vanadium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 849      Vanadium  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 850      Vanadium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 851      Vanadium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 852      Vanadium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 853      Vanadium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 854      Vanadium  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 855      Vanadium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 856      Vanadium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 857      Vanadium  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 858      Vanadium  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 859      Vanadium  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 860      Vanadium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 861      Vanadium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 862      Vanadium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 863      Vanadium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 864      Vanadium  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 865      Vanadium  µg/g     0.02163  2018-10-12 00:00:00  736979.0
# 866      Vanadium  µg/g     0.02385  2018-10-12 00:00:00  736979.0
# 867      Vanadium  µg/g     0.02234  2018-10-11 00:00:00  736978.0
# 868      Vanadium  µg/g     0.02101  2018-10-12 00:00:00  736979.0
# 869      Vanadium  µg/g     0.02577  2018-10-12 00:00:00  736979.0
# 870          Zinc  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 871          Zinc  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 872          Zinc  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 873          Zinc  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 874          Zinc  µg/g         NaN  2018-10-08 00:00:00  736975.0
# 875          Zinc  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 876          Zinc  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 877          Zinc  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 878          Zinc  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 879          Zinc  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 880          Zinc  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 881          Zinc  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 882          Zinc  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 883          Zinc  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 884          Zinc  µg/g         NaN  2018-10-10 00:00:00  736977.0
# 885          Zinc  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 886          Zinc  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 887          Zinc  µg/g         NaN  2018-08-10 00:00:00  736916.0
# 888          Zinc  µg/g         NaN  2018-08-11 00:00:00  736917.0
# 889          Zinc  µg/g         NaN  2018-09-11 00:00:00  736948.0
# 890          Zinc  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 891          Zinc  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 892          Zinc  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 893          Zinc  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 894          Zinc  µg/g         NaN  2018-10-06 00:00:00  736973.0
# 895          Zinc  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 896          Zinc  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 897          Zinc  µg/g         NaN  2018-10-11 00:00:00  736978.0
# 898          Zinc  µg/g         NaN  2018-10-12 00:00:00  736979.0
# 899          Zinc  µg/g         NaN  2018-10-12 00:00:00  736979.0

# %% [markdown]
# Reading the WQG and SQG

# %%
QG_df = pd.read_excel(QG_folder_file, sheet_name=QG_file_sheet_name)
print('Quality guidelines from: '+str(QG_file_sheet_name))
# Out:
# Quality guidelines from: WQG

# %% [markdown]
# plot the IMPACT, EMMA, with the measurement data and the Quality Guidelines

# %%
fig, axes = plt.subplots(nrows=32, ncols=1, dpi = 200)
#the nrows is a problem, here we have 27, if we ever have more we'll be plotting less

fig.set_figwidth(10)
fig.set_figheight(120)


axes = axes.ravel()#this combines multidimensional arrays to one dimensio, probably does nothing here
for m,i in enumerate(IMPACT_locations): # Legend-location
    for n,j in enumerate(IMPACT_df[i].columns[startcolumn:-1]): # Label-concentration
        #print(len(IMPACT_df[i].columns))

        if m==0:

            axes[n].plot_date(dates_IMPACT, IMPACT_df[i][j], ls='--',marker= '',c=IMPACT_color_ls[m], label='IMPACT Prediction'+'-'+i)   # To plot IMPACT           
            axes[n].set_ylabel(j + ' ' + '(' + unit_ls[n] + ')', fontsize=8)            
            axes[n].xaxis.set_major_locator(mdates.YearLocator(1)) # 10 years of interval
            axes[n].xaxis.set_major_formatter(DateFormatter("%Y"))            
            axes[n].tick_params(labelsize = 8)
          
        if m==1:
            axes[n].plot_date(dates_IMPACT, IMPACT_df[i][j], ls='-.',marker='',c=IMPACT_color_ls[m], label='IMPACT Prediction'+'-'+i)
                   
        if m==2:
            axes[n].plot_date(dates_IMPACT, IMPACT_df[i][j], ls=':',marker='',c=IMPACT_color_ls[m], label='IMPACT Prediction'+'-'+i)
                   
#             print(j)
#             print(len(EMMA_Stat_df.loc[EMMA_Stat_df['Parameter'] == j]))
            if len(EMMA_Stat_df.loc[EMMA_Stat_df['Parameter'] == j])==0:
                continue
            geom_m_EMMA = EMMA_Stat_df.loc[EMMA_Stat_df['Parameter'] == j]['Geometric_Mean'].iloc[0]
            axes[n].plot_date([start_date,end_date],[geom_m_EMMA, geom_m_EMMA],ls='-',marker=' ',
                              c=geom_m_EMMA_ls[0], label='Observed Geometric Mean')
            
            for p,l in enumerate(EMMA_location_alias):
                #print(p,l)
                grouped_F = EMMA_df_s_F[EMMA_location_alias[p]].groupby('Parameter_ID')
                grouped_T = EMMA_df_s_T[EMMA_location_alias[p]].groupby('Parameter_ID')
                if j in (grouped_T.describe().index): # To check if the concentration in EMMA-Sometimes because of the end date we might loose some concentrations
                    EMMA_copc_F_df = grouped_F.get_group(j)
                    EMMA_copc_T_df = grouped_T.get_group(j)
                    
                    temp_ls_F = list(EMMA_copc_F_df.columns[EMMA_copc_F_df.columns.str.endswith('False')])
                    temp_ls_T = list(EMMA_copc_T_df.columns[EMMA_copc_T_df.columns.str.endswith('True')])
                    
                    col_ls_temp_F_0 = EMMA_df_s_F[l].columns
                    col_ls_temp_F_1 = [s for s in col_ls_temp_F_0 if l in s]
                    label_F_ls = [word[:-5] for word in col_ls_temp_F_1]
                    
                    col_ls_temp_T_0 = EMMA_df_s_T[l].columns
                    col_ls_temp_T_1 = [s for s in col_ls_temp_T_0 if l in s]
                    label_T_ls = [word[:-4] for word in col_ls_temp_T_1]
                        
   
                    if len(EMMA_copc_T_df.columns)>5:
                            
                            for o,k in enumerate(temp_ls_F): # To plot EMMA 
                                axes[n].plot_date(EMMA_copc_F_df['Time'], EMMA_copc_F_df[k], marker=EMMA_marker_ls[p], markersize=5,c=cols_ls_2[o],
                                                  label='Observed Data'+'-'+ label_F_ls[o] )  
    
                            for o,k in enumerate(temp_ls_T): # To plot EMMA
                                axes[n].plot_date(EMMA_copc_T_df['Time'], EMMA_copc_T_df[k],
                                                  marker=EMMA_marker_ls[p], markerfacecolor='white',markersize=5,c=cols_ls_2[o],
                                                  label='Below Detection Limit'+'-'+label_T_ls[o]) 
                    else:
    
                            for o,k in enumerate(temp_ls_F): # To plot EMMA 
                                axes[n].plot_date(EMMA_copc_F_df['Time'], EMMA_copc_F_df[k], marker=EMMA_marker_ls[p], markersize=5,c=cols_ls_1[p],
                                                    label='Observed Data'+'-'+ label_F_ls[o] )  
    
                            for o,k in enumerate(temp_ls_T): # To plot EMMA
                                axes[n].plot_date(EMMA_copc_T_df['Time'], EMMA_copc_T_df[k],
                                                  marker=EMMA_marker_ls[p], markerfacecolor='white',markersize=5,c=cols_ls_1[p],
                                                  label='Below Detection Limit'+'-'+label_T_ls[o])
                        

            fig.tight_layout()
    
            bbox = axes[n].get_tightbbox(fig.canvas.get_renderer())
            fig.savefig(str(IMPACT_EMMA_Fish_Plots_folder)+'/'+"{}.png".format(j),
                  bbox_inches=bbox.transformed(fig.dpi_scale_trans.inverted()))    
            
            handles, labels = axes[n].get_legend_handles_labels()
#print('IMPACT figures are plotted and saved in '+str(IMPACT_plots_folder))
plt.close('all')
leg_fig = pylab.figure(figsize=(5,3), dpi=200)
leg_ax = fig.add_subplot(111)
leg_fig.legend(handles, labels, 'center', ncol=3)
leg_fig.savefig(str(IMPACT_EMMA_Fish_Plots_folder)+'/IMPACT_EMMA_LocalInflow_QG_legend.png',bbox_inches='tight')

# %%
(IMPACT_df['Broach Lake'].columns)
# Out:
# Index(['Time', 'Ammonia (as N)', 'Arsenic', 'Conductivity (Field)', 'Calcium', 'Cadmium', 'Chloride', 'Cobalt', 'Chromium', 'Cesium', 'Copper', 'Iron', 'Magnesium', 'Manganese', 'Molybdenum', 'Ammonia as N', 'Nitrate', 'Sodium', 'Nickel', 'Nitrate (as N)', 'Lead', 'Lead-210', 'Polonium-210', 'Radium-226', 'Radon-222', 'Sulphate', 'Selenium', 'Thorium-230', 'Uranium', 'Uranium-234', 'Uranium-238', 'Vanadium', 'Zinc', 'Date_Time'], dtype='object')

# %%
EMMA_df.Parameter_ID.unique()
# Out:
# array(['% Moisture', 'Aluminum', 'Antimony', 'Arsenic', 'Barium',
#        'Beryllium', 'Boron', 'Cadmium', 'Chromium', 'Cobalt', 'Copper',
#        'Iron', 'Lead', 'Lead-210', 'Manganese', 'Mercury', 'Molybdenum',
#        'Nickel', 'Polonium-210', 'Radium-226', 'Selenium', 'Silver',
#        'Strontium', 'Thallium', 'Thorium-230', 'Tin', 'Titanium',
#        'Uranium', 'Vanadium', 'Zinc'], dtype=object)

# %%
pwd
# Out:
# 'C:\\Users\\ssabahi\\Desktop\\Plot_Generator\\Feb_18_2020\\NexGen'
